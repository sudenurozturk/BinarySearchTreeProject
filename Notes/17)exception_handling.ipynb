# %% [markdown]
# <a href="https://colab.research.google.com/github/sudenurozturk/BinarySearchTreeProject/blob/main/Notes/17)exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number1= 15
number2 = input('Please enter a Number: ')
print(number1 + number2)
# Out:
# Please enter a Number: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-676bf0715fc6> in <cell line: 0>()
#       1 number1= 15
#       2 number2 = input('Please enter a Number: ')
# ----> 3 print(number1 + number2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
celsius = 18
if celsius > 20:
  print('Good 🟩')
  else:
    print('Cold ❄️')
# Out:
#   File "<ipython-input-2-f311b3d73e28>", line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
def divide(number1, number2):
   number1_integer = int(number1)
   number2_integer = int(number2)
   return number1_integer / number2_integer

number1 = input('Please provide number1: ')
number2 = input('Please provide number2: ')

print(divide(number1, number2))
# Out:
# Please provide number1: apple
# Please provide number2: banana
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-9adc0ee1d89a> in <cell line: 0>()
#       7 number2 = input('Please provide number2: ')
#       8
# ----> 9 print(divide(number1, number2))
#
# <ipython-input-4-9adc0ee1d89a> in divide(number1, number2)
#       1 def divide(number1, number2):
# ----> 2    number1_integer = int(number1)
#       3    number2_integer = int(number2)
#       4    return number1_integer / number2_integer
#       5
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
def divide(number1, number2):
   try:
       number1_integer = int(number1)
       number2_integer = int(number2)
       return number1_integer / number2_integer

   except:
       return 'Only integers are allowed! Try again.'

number1 = input('Please provide a number1: ')
number2 = input('Please provide a number2: ')

print(divide(number1, number2))
# Out:
# Please provide a number1: banana
# Please provide a number2: apple
# Only integers are allowed! Try again.

# %%
def divide(number1, number2):
   try:
       number1_integer = int(number1)
       number2_integer = int(number2)
       return number1_integer / number2_integer

   except ValueError:
       return 'Only integers are allowed!'

   except ZeroDivisionError:
       return 'You cannot divide any number by zero!'



number1 = input('Please provide a number1: ')
number2 = input('Please provide a number2: ')

print(divide(number1, number2))
# Out:
# Please provide a number1: 10
# Please provide a number2: 0
# You cannot divide any number by zero!
